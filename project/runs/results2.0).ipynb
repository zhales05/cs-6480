# %% [markdown]
# # Podcast Ad Detection Classifier
#
# CS 6480 Deep Learning — Course Project
#
# **Goal:** Detect advertisement segments in podcast transcripts using three approaches:
# 1. Keyword/regex baseline
# 2. TF-IDF + Logistic Regression
# 3. Fine-tuned DistilBERT
#
# **Training data:** 2,000 LLM-generated synthetic segments (balanced 50/50) + real segments from 8 YouTube videos (mixed in to close the synthetic-to-real domain gap)
#
# **Test data:** Real segments from 18 held-out YouTube videos labeled via SponsorBlock (split by video to prevent leakage)

# %% [markdown]
# ## 1. Setup & Imports

# %%
# Colab: install dependencies & upload data
# !pip install -q transformers[torch] accelerate scikit-learn

import os
if not os.path.exists("data"):
    os.makedirs("data", exist_ok=True)
    from google.colab import files
    print("Upload synthetic_train.jsonl")
    uploaded = files.upload()
    for name, content in uploaded.items():
        with open(f"data/{name}", "wb") as f:
            f.write(content)
    print("Upload real_test.jsonl")
    uploaded = files.upload()
    for name, content in uploaded.items():
        with open(f"data/{name}", "wb") as f:
            f.write(content)

# %%
import json
import re
import random
import warnings
from collections import Counter
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    precision_recall_fscore_support,
    ConfusionMatrixDisplay,
)

import torch
from torch.utils.data import Dataset, DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    EarlyStoppingCallback,
)

warnings.filterwarnings("ignore")
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

print(f"PyTorch {torch.__version__}")
print(f"Device: {'cuda' if torch.cuda.is_available() else 'cpu'}")
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# PyTorch 2.10.0+cu128
# Device: cuda

# %% [markdown]
# ## 2. Data Loading & Exploration

# %%
DATA_DIR = Path("data")

def load_jsonl(path):
    with open(path) as f:
        return [json.loads(line) for line in f if line.strip()]

synthetic = load_jsonl(DATA_DIR / "synthetic_train.jsonl")
all_real = load_jsonl(DATA_DIR / "real_test.jsonl")

syn_texts = [s["text"] for s in synthetic]
syn_labels = [s["label"] for s in synthetic]

# --- Split real data by video: 8 videos for training, rest for testing ---
all_videos = sorted(set(r["video_id"] for r in all_real))
random.seed(42)
random.shuffle(all_videos)

N_TRAIN_VIDEOS = 8
train_videos = set(all_videos[:N_TRAIN_VIDEOS])
test_videos = set(all_videos[N_TRAIN_VIDEOS:])

real_train_data = [r for r in all_real if r["video_id"] in train_videos]
real_test_data = [r for r in all_real if r["video_id"] in test_videos]

real_train_texts = [r["text"] for r in real_train_data]
real_train_labels = [r["label"] for r in real_train_data]
real_texts = [r["text"] for r in real_test_data]
real_labels = [r["label"] for r in real_test_data]

print("=== Synthetic Training Data ===")
print(f"  Total: {len(synthetic)}")
print(f"  Ads: {sum(syn_labels)}, Non-ads: {len(syn_labels) - sum(syn_labels)}")
syn_cats = Counter(s["category"] for s in synthetic)
print(f"  Categories: {len(syn_cats)}")
for cat, count in syn_cats.most_common():
    print(f"    {cat}: {count}")

print(f"\n=== Real Data — Train Videos ({len(train_videos)} videos) ===")
print(f"  Total: {len(real_train_data)}")
print(f"  Ads: {sum(real_train_labels)}, Non-ads: {len(real_train_labels) - sum(real_train_labels)}")
for vid in sorted(train_videos):
    segs = [r for r in real_train_data if r["video_id"] == vid]
    ads = sum(1 for r in segs if r["label"] == 1)
    print(f"    {vid}: {len(segs)} segments ({ads} ads)")

print(f"\n=== Real Data — Test Videos ({len(test_videos)} videos) ===")
print(f"  Total: {len(real_test_data)}")
print(f"  Ads: {sum(real_labels)}, Non-ads: {len(real_labels) - sum(real_labels)}")
for vid in sorted(test_videos):
    segs = [r for r in real_test_data if r["video_id"] == vid]
    ads = sum(1 for r in segs if r["label"] == 1)
    print(f"    {vid}: {len(segs)} segments ({ads} ads)")
# Out:
# === Synthetic Training Data ===
#   Total: 2000
#   Ads: 1000, Non-ads: 1000
#   Categories: 15
#     host_read_ad: 300
#     interview: 200
#     promo_code_ad: 200
#     midroll_transition: 150
#     monologue: 150
#     storytelling: 150
#     subtle_ad: 100
#     banter: 100
#     product_testimonial_ad: 100
#     news_recap: 100
#     intro_outro: 100
#     technical_discussion: 100
#     preroll_ad: 100
#     product_mention_organic: 100
#     cross_promo: 50
#
# === Real Data — Train Videos (8 videos) ===
#   Total: 1405
#   Ads: 23, Non-ads: 1382
#     6HVYHNTDOFs: 58 segments (4 ads)
#     7OLVwZeMCfY: 339 segments (1 ads)
#     H9rF1CSSh-w: 519 segments (4 ads)
#     KGVpKPNUdzA: 21 segments (1 ads)
#     NIk_0AW5hFU: 82 segments (3 ads)
#     XKSjCOKDtpk: 69 segments (5 ads)
#     cMx139eTxoc: 94 segments (4 ads)
#     iKx3gAODybU: 223 segments (1 ads)
#
# === Real Data — Test Videos (23 videos) ===
#   Total: 1681
#   Ads: 78, Non-ads: 1603
#     -YNk9_e4pg4: 41 segments (5 ads)
#     -q2n5DkDoMQ: 46 segments (4 ads)
#     1SJiTwbSI58: 287 segments (3 ads)
#     3w0KeFOB698: 41 segments (4 ads)
#     5aS-8QCRdGE: 24 segments (1 ads)
#     9szhjhO9epA: 42 segments (4 ads)
#     DqAKQwagCDg: 28 segments (4 ads)
#     FRI78tq9Eik: 20 segments (3 ads)
#     HBluLfX2F_k: 91 segments (3 ads)
#     MiUHjLxm3V0: 111 segments (4 ads)
#     Ol18JoeXlVI: 54 segments (5 ads)
#     P-4pbFcERnk: 63 segments (3 ads)
#     PPJ6NJkmDAo: 55 segments (5 ads)
#     QtxVdC7pBQM: 80 segments (3 ads)
#     Y-W-w8yNiKU: 66 segments (3 ads)
#     YSJY3DvnybE: 62 segments (4 ads)
#     ZxobPzkE4r0: 27 segments (4 ads)
#     aoag03mSuXQ: 105 segments (3 ads)
#     eXa2ndhmatI: 23 segments (2 ads)
#     iGeXGdYE7UE: 31 segments (3 ads)
#     jjp3WC8Unj8: 110 segments (3 ads)
#     kBX5WH9b4M4: 21 segments (3 ads)
#     vif8NQcjVf0: 253 segments (2 ads)

# %%
# Text length distributions
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

syn_wc = [len(t.split()) for t in syn_texts]
real_wc = [len(t.split()) for t in real_texts]

axes[0].hist(syn_wc, bins=30, alpha=0.7, edgecolor="black")
axes[0].set_title("Synthetic — Word Count Distribution")
axes[0].set_xlabel("Words per segment")
axes[0].axvline(np.mean(syn_wc), color="red", linestyle="--", label=f"mean={np.mean(syn_wc):.0f}")
axes[0].legend()

axes[1].hist(real_wc, bins=30, alpha=0.7, color="orange", edgecolor="black")
axes[1].set_title("Real Test — Word Count Distribution")
axes[1].set_xlabel("Words per segment")
axes[1].axvline(np.mean(real_wc), color="red", linestyle="--", label=f"mean={np.mean(real_wc):.0f}")
axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# Filler word prevalence in synthetic data — a potential domain gap issue
fillers = ["uh", "um", "like", "you know", "honestly", "actually", "basically"]
all_real_texts = [r["text"] for r in all_real]

print("Filler word prevalence in synthetic data:")
for filler in fillers:
    count = sum(1 for t in syn_texts if filler in t.lower())
    print(f"  '{filler}': {count}/{len(syn_texts)} ({count/len(syn_texts)*100:.1f}%)")

print("\nFiller word prevalence in real data:")
for filler in fillers:
    count = sum(1 for t in all_real_texts if filler in t.lower())
    print(f"  '{filler}': {count}/{len(all_real_texts)} ({count/len(all_real_texts)*100:.1f}%)")
# Out:
# Filler word prevalence in synthetic data:
#   'uh': 0/2000 (0.0%)
#   'um': 165/2000 (8.2%)
#   'like': 275/2000 (13.8%)
#   'you know': 26/2000 (1.3%)
#   'honestly': 4/2000 (0.2%)
#   'actually': 165/2000 (8.2%)
#   'basically': 0/2000 (0.0%)
#
# Filler word prevalence in real data:
#   'uh': 46/3086 (1.5%)
#   'um': 795/3086 (25.8%)
#   'like': 1474/3086 (47.8%)
#   'you know': 576/3086 (18.7%)
#   'honestly': 14/3086 (0.5%)
#   'actually': 386/3086 (12.5%)
#   'basically': 126/3086 (4.1%)

# %%
# Example segments
print("=== Example Synthetic Ad ===")
ad_ex = next(s for s in synthetic if s["label"] == 1)
print(f"  Category: {ad_ex['category']}")
print(f"  Text: {ad_ex['text'][:300]}...")

print("\n=== Example Synthetic Non-Ad ===")
nonad_ex = next(s for s in synthetic if s["label"] == 0)
print(f"  Category: {nonad_ex['category']}")
print(f"  Text: {nonad_ex['text'][:300]}...")

print("\n=== Example Real Ad ===")
real_ad = next(r for r in real_test if r["label"] == 1)
print(f"  Video: {real_ad['video_id']}")
print(f"  Text: {real_ad['text'][:300]}...")

print("\n=== Example Real Non-Ad ===")
real_nonad = next(r for r in real_test if r["label"] == 0)
print(f"  Video: {real_nonad['video_id']}")
print(f"  Text: {real_nonad['text'][:300]}...")
# Out:
# === Example Synthetic Ad ===
#   Category: midroll_transition
#   Text: Speaking of things that work, let me tell you about CodeForge IDE. I am pretty picky about what I recommend and CodeForge IDE is one of the few that I genuinely stand behind. Right, codeforge.dev, link in the show notes. The more I think about it, the more convinced I am. And I think most people wou...
#
# === Example Synthetic Non-Ad ===
#   Category: monologue
#   Text: Let me paint a picture for you. Imagine you are lying in bed at night and you start thinking about marine biology. And you realize that everything you thought you knew about it is kind of wrong. That is where I was last week and it sent me down this rabbit hole that I want to share with you today, a...
#
# === Example Real Ad ===
#   Video: vif8NQcjVf0
#   Text: And in the meantime, my, my favorite answer is eliminate waste. You know, we've, we've got all that idle power. I want to evacuate it as fast as possible. Yeah, there, there's a lot of low hanging fruit here on earth. Yeah. The working utilize for the AI scaling, quick pause, quick 30 second. Thank ...
#
# === Example Real Non-Ad ===
#   Video: vif8NQcjVf0
#   Text: The following is a conversation with Jensen Huang, CEO of Invidia, one of the most important and influential companies in the history of human civilization. Invidia is the engine powering the AI revolution, and a lot of its success can be directly attributed to Jensen's sheer force of will and as ma...

# %% [markdown]
# ## 3. Preprocessing
#
# The synthetic data generator injected filler words ("honestly", "actually", "like", etc.) into 50-70% of segments across both classes. This could create a spurious shortcut for the model.
#
# We prepare **two versions** of the data — raw and cleaned — and train each model on both to empirically measure whether filler removal helps generalization to real data.
#
# **Domain adaptation:** We mix real segments from 8 held-out training videos into the synthetic training set. This exposes the model to real Whisper transcription style, genuine ad phrasing, and natural speech patterns — helping bridge the synthetic-to-real gap. The remaining 18 videos are held out strictly for testing (no video appears in both splits).

# %%
FILLER_PATTERN = re.compile(
    r"\b(honestly|actually|basically|like|look|right|um|uh|well|you know)\b",
    re.IGNORECASE,
)

def clean_text(text):
    text = text.lower().strip()
    text = FILLER_PATTERN.sub("", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Prepare raw and cleaned versions of synthetic data
syn_texts_raw = syn_texts
syn_texts_clean = [clean_text(t) for t in syn_texts]
real_texts_raw = real_texts
real_texts_clean = [clean_text(t) for t in real_texts]

# Clean versions of real train data
real_train_texts_clean = [clean_text(t) for t in real_train_texts]

# Upsample real ad segments 15x to address class imbalance
real_ads = [r for r in real_train_data if r["label"] == 1]
real_train_data_upsampled = real_train_data + real_ads * 15
real_train_texts_up = [r["text"] for r in real_train_data_upsampled]
real_train_labels_up = [r["label"] for r in real_train_data_upsampled]
real_train_texts_clean_up = [clean_text(t) for t in real_train_texts_up]

print(f"Real train before upsampling: {len(real_train_data)} ({sum(real_train_labels)} ads)")
print(f"Real train after upsampling:  {len(real_train_data_upsampled)} ({sum(real_train_labels_up)} ads)")

# Train/val split on synthetic data — same indices for both versions
train_idx, val_idx = train_test_split(
    range(len(syn_texts)), test_size=0.2, stratify=syn_labels, random_state=42
)

# Synthetic train + upsampled real train mixed together
train_texts_raw = [syn_texts_raw[i] for i in train_idx] + real_train_texts_up
train_texts_clean = [syn_texts_clean[i] for i in train_idx] + real_train_texts_clean_up
train_labels = [syn_labels[i] for i in train_idx] + real_train_labels_up

# Validation stays synthetic-only (measures how well model learns the task)
val_texts_raw = [syn_texts_raw[i] for i in val_idx]
val_texts_clean = [syn_texts_clean[i] for i in val_idx]
val_labels = [syn_labels[i] for i in val_idx]

syn_in_train = len(train_idx)
real_in_train = len(real_train_texts_up)
print(f"\nTrain: {len(train_labels)} total ({syn_in_train} synthetic + {real_in_train} real [upsampled])")
print(f"  Ads: {sum(train_labels)}, Non-ads: {len(train_labels) - sum(train_labels)}")
print(f"Val:   {len(val_labels)} (synthetic only, {sum(val_labels)} ads)")
print(f"Test:  {len(real_labels)} (real held-out, {sum(real_labels)} ads)")

# Show cleaning effect
print(f"\nExample cleaning:")
print(f"  Raw:     {syn_texts_raw[0][:150]}...")
print(f"  Cleaned: {syn_texts_clean[0][:150]}...")
# Out:
# Real train before upsampling: 1405 (23 ads)
# Real train after upsampling:  1750 (368 ads)
#
# Train: 3350 total (1600 synthetic + 1750 real [upsampled])
#   Ads: 1168, Non-ads: 2182
# Val:   400 (synthetic only, 200 ads)
# Test:  1681 (real held-out, 78 ads)
#
# Example cleaning:
#   Raw:     Speaking of things that work, let me tell you about CodeForge IDE. I am pretty picky about what I recommend and CodeForge IDE is one of the few that I...
#   Cleaned: speaking of things that work, let me tell you about codeforge ide. i am pretty picky about what i recommend and codeforge ide is one of the few that i...

# %%
# Shared evaluation helper
all_results = []

def evaluate(y_true, y_pred, model_name, dataset_name, verbose=True):
    p, r, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="binary", zero_division=0)
    acc = np.mean(np.array(y_true) == np.array(y_pred))
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    result = {
        "Model": model_name, "Dataset": dataset_name,
        "Accuracy": acc, "Precision": p, "Recall": r, "F1": f1,
        "TP": tp, "FP": fp, "FN": fn, "TN": tn,
    }
    all_results.append(result)
    if verbose:
        print(f"\n{model_name} on {dataset_name}:")
        print(f"  Accuracy={acc:.3f}  Precision={p:.3f}  Recall={r:.3f}  F1={f1:.3f}")
        print(f"  TP={tp}  FP={fp}  FN={fn}  TN={tn}")
    return result

# %% [markdown]
# ## 4. Model 1 — Keyword/Regex Baseline\n\nA simple pattern matcher that predicts "ad" if the text contains any common ad-related phrases. This provides an interpretable lower bound.

# %%
AD_PATTERNS = [
    re.compile(p, re.IGNORECASE) for p in [
        r"sponsor(ed|s)?\s+by",
        r"promo\s*code",
        r"use\s+code\s+\w+",
        r"brought\s+to\s+you\s+by",
        r"percent\s+off",
        r"\d+%\s+off",
        r"free\s+trial",
        r"\.com\s*(slash|\/)\s*\w+",
        r"thank\s+(you\s+)?to\s+(our\s+)?sponsors?",
        r"link\s+in\s+the\s+description",
        r"discount\s+(code|on)",
        r"check\s+(them\s+)?out\s+at\s+\w+",
        r"sign\s+up\s+(at|with)",
        r"go\s+to\s+\w+\.\w+",
        r"special\s+offer",
        r"limited\s+time",
        r"(first|next)\s+\d+\s+(order|month|purchase)",
    ]
]

def keyword_predict(text):
    for pattern in AD_PATTERNS:
        if pattern.search(text):
            return 1
    return 0

# Evaluate on validation and real test (raw text — regex is content-based)
kw_val_preds = [keyword_predict(t) for t in val_texts_raw]
kw_real_preds = [keyword_predict(t) for t in real_texts_raw]

evaluate(val_labels, kw_val_preds, "Keyword", "Validation")
evaluate(real_labels, kw_real_preds, "Keyword", "Real Test")
# Out:
# Keyword on Validation:
#   Accuracy=0.865  Precision=0.980  Recall=0.745  F1=0.847
#   TP=149  FP=3  FN=51  TN=197
#
# Keyword on Real Test:
#   Accuracy=0.965  Precision=0.828  Recall=0.308  F1=0.449
#   TP=24  FP=5  FN=54  TN=1598
# {'Model': 'Keyword',
#  'Dataset': 'Real Test',
#  'Accuracy': np.float64(0.9649018441403926),
#  'Precision': 0.8275862068965517,
#  'Recall': 0.3076923076923077,
#  'F1': 0.4485981308411215,
#  'TP': np.int64(24),
#  'FP': np.int64(5),
#  'FN': np.int64(54),
#  'TN': np.int64(1598)}

# %% [markdown]
# ## 5. Model 2 — TF-IDF + Logistic Regression\n\nA statistical baseline using TF-IDF features with bigrams. Trained on both raw and cleaned text to measure the effect of filler removal.

# %%
def train_tfidf_lr(train_texts, val_texts, real_texts, train_labels, val_labels, real_labels, label):
    tfidf = TfidfVectorizer(max_features=5000, ngram_range=(1, 2), min_df=2)
    X_train = tfidf.fit_transform(train_texts)
    X_val = tfidf.transform(val_texts)
    X_real = tfidf.transform(real_texts)

    lr = LogisticRegression(max_iter=1000, class_weight="balanced", C=1.0, random_state=42)
    lr.fit(X_train, train_labels)

    val_preds = lr.predict(X_val)
    real_preds = lr.predict(X_real)

    # Get probability scores for threshold tuning
    val_probs = lr.predict_proba(X_val)[:, 1]
    real_probs = lr.predict_proba(X_real)[:, 1]

    evaluate(val_labels, val_preds.tolist(), f"TF-IDF+LR ({label})", "Validation")
    evaluate(real_labels, real_preds.tolist(), f"TF-IDF+LR ({label})", "Real Test")

    return tfidf, lr, real_preds, val_probs, real_probs

# Train on raw text
print("=" * 50)
print("TF-IDF + LR on RAW text")
print("=" * 50)
tfidf_raw, lr_raw, lr_raw_real_preds, val_probs_raw, real_probs_raw = train_tfidf_lr(
    train_texts_raw, val_texts_raw, real_texts_raw,
    train_labels, val_labels, real_labels, "raw"
)

# Train on cleaned text
print("\n" + "=" * 50)
print("TF-IDF + LR on CLEANED text")
print("=" * 50)
tfidf_clean, lr_clean, lr_clean_real_preds, val_probs_clean, real_probs_clean = train_tfidf_lr(
    train_texts_clean, val_texts_clean, real_texts_clean,
    train_labels, val_labels, real_labels, "clean"
)
# Out:
# ==================================================
# TF-IDF + LR on RAW text
# ==================================================
#
# TF-IDF+LR (raw) on Validation:
#   Accuracy=1.000  Precision=1.000  Recall=1.000  F1=1.000
#   TP=200  FP=0  FN=0  TN=200
#
# TF-IDF+LR (raw) on Real Test:
#   Accuracy=0.965  Precision=0.885  Recall=0.295  F1=0.442
#   TP=23  FP=3  FN=55  TN=1600
#
# ==================================================
# TF-IDF + LR on CLEANED text
# ==================================================
#
# TF-IDF+LR (clean) on Validation:
#   Accuracy=1.000  Precision=1.000  Recall=1.000  F1=1.000
#   TP=200  FP=0  FN=0  TN=200
#
# TF-IDF+LR (clean) on Real Test:
#   Accuracy=0.966  Precision=0.920  Recall=0.295  F1=0.447
#   TP=23  FP=2  FN=55  TN=1601

# %%
# Top features for each class (cleaned model)
feature_names = tfidf_clean.get_feature_names_out()
coefs = lr_clean.coef_[0]
top_ad = np.argsort(coefs)[-20:][::-1]
top_nonad = np.argsort(coefs)[:20]

print("Top 20 features — AD class (cleaned model):")
for i in top_ad:
    print(f"  {feature_names[i]:30s} coef={coefs[i]:.3f}")

print("\nTop 20 features — NON-AD class (cleaned model):")
for i in top_nonad:
    print(f"  {feature_names[i]:30s} coef={coefs[i]:.3f}")
# Out:
# Top 20 features — AD class (cleaned model):
#   code                           coef=3.449
#   com                            coef=2.695
#   co                             coef=2.232
#   check                          coef=2.126
#   link                           coef=2.102
#   use                            coef=1.997
#   quick                          coef=1.983
#   link in                        coef=1.844
#   the description                coef=1.776
#   slash                          coef=1.758
#   description                    coef=1.743
#   use code                       coef=1.645
#   check them                     coef=1.631
#   them out                       coef=1.516
#   go to                          coef=1.483
#   sponsor                        coef=1.448
#   brilliant                      coef=1.435
#   deal                           coef=1.390
#   now                            coef=1.372
#   genuinely                      coef=1.335
#
# Top 20 features — NON-AD class (cleaned model):
#   the                            coef=-3.549
#   of                             coef=-2.417
#   and                            coef=-2.207
#   was                            coef=-2.200
#   there                          coef=-2.147
#   what                           coef=-2.135
#   he                             coef=-1.979
#   have                           coef=-1.853
#   you                            coef=-1.835
#   going                          coef=-1.707
#   in                             coef=-1.647
#   are                            coef=-1.617
#   so                             coef=-1.557
#   because                        coef=-1.516
#   had                            coef=-1.504
#   re                             coef=-1.503
#   some                           coef=-1.428
#   be                             coef=-1.381
#   going to                       coef=-1.376
#   then                           coef=-1.354

# %% [markdown]
# ## 5b. Threshold Tuning & PR Curves
#
# The default classification threshold of 0.5 assumes equal cost for false positives and false negatives. Since we prioritize **recall** (catching ads), we:
#
# 1. **Sweep thresholds** from 0.01 to 0.99 on the validation set
# 2. **Optimize F-beta (β=2)** which weights recall 4× more than precision
# 3. **Plot Precision-Recall curves** to visualize the tradeoff at every threshold
# 4. **Re-evaluate on real test** using the tuned threshold
#
# This also addresses the class imbalance gap: the model is trained on balanced 50/50 data but tested on ~1% ad data. Threshold tuning corrects the decision boundary for the real distribution.

# %%
from sklearn.metrics import fbeta_score, precision_recall_curve

def sweep_threshold(y_true, probs, model_name, beta=2):
    """Sweep thresholds and find optimal for F-beta score."""
    thresholds = np.arange(0.01, 1.0, 0.01)
    f_scores = []
    precisions = []
    recalls = []
    for thresh in thresholds:
        preds = (probs >= thresh).astype(int)
        f = fbeta_score(y_true, preds, beta=beta, zero_division=0)
        p, r, _, _ = precision_recall_fscore_support(y_true, preds, average="binary", zero_division=0)
        f_scores.append(f)
        precisions.append(p)
        recalls.append(r)

    best_idx = np.argmax(f_scores)
    best_thresh = thresholds[best_idx]
    best_f = f_scores[best_idx]

    print(f"{model_name}:")
    print(f"  Default (0.50) — F{beta}={fbeta_score(y_true, (probs >= 0.5).astype(int), beta=beta, zero_division=0):.3f}")
    print(f"  Optimal ({best_thresh:.2f}) — F{beta}={best_f:.3f}")
    print(f"  At optimal: Precision={precisions[best_idx]:.3f}, Recall={recalls[best_idx]:.3f}")

    return best_thresh, thresholds, f_scores, precisions, recalls

# Sweep on validation set
print("=== Threshold Sweep on Validation Set (F2 optimization) ===\n")
thresh_raw, ts_raw, fs_raw, ps_raw, rs_raw = sweep_threshold(
    val_labels, val_probs_raw, "TF-IDF+LR (raw)"
)
thresh_clean, ts_clean, fs_clean, ps_clean, rs_clean = sweep_threshold(
    val_labels, val_probs_clean, "TF-IDF+LR (clean)"
)
# Out:
# === Threshold Sweep on Validation Set (F2 optimization) ===
#
# TF-IDF+LR (raw):
#   Default (0.50) — F2=1.000
#   Optimal (0.45) — F2=1.000
#   At optimal: Precision=1.000, Recall=1.000
# TF-IDF+LR (clean):
#   Default (0.50) — F2=1.000
#   Optimal (0.43) — F2=1.000
#   At optimal: Precision=1.000, Recall=1.000

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Top row: F2 score vs threshold
for ax, ts, fs, thresh, label in [
    (axes[0, 0], ts_raw, fs_raw, thresh_raw, "TF-IDF+LR (raw)"),
    (axes[0, 1], ts_clean, fs_clean, thresh_clean, "TF-IDF+LR (clean)"),
]:
    ax.plot(ts, fs, color="steelblue", linewidth=2)
    ax.axvline(0.5, color="gray", linestyle="--", alpha=0.5, label="Default (0.50)")
    ax.axvline(thresh, color="red", linestyle="--", label=f"Optimal ({thresh:.2f})")
    ax.set_xlabel("Threshold")
    ax.set_ylabel("F2 Score")
    ax.set_title(f"{label} — F2 vs Threshold")
    ax.legend()
    ax.set_xlim(0, 1)

# Bottom row: Precision-Recall curves
for ax, probs, labels, label in [
    (axes[1, 0], val_probs_raw, val_labels, "TF-IDF+LR (raw)"),
    (axes[1, 1], val_probs_clean, val_labels, "TF-IDF+LR (clean)"),
]:
    precision, recall, thresholds = precision_recall_curve(labels, probs)
    ax.plot(recall, precision, color="coral", linewidth=2)
    ax.set_xlabel("Recall")
    ax.set_ylabel("Precision")
    ax.set_title(f"{label} — Precision-Recall Curve (Val)")
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1.05)
    ax.fill_between(recall, precision, alpha=0.1, color="coral")

plt.suptitle("Threshold Tuning — Validation Set", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
# Re-evaluate on real test using tuned thresholds
print("=== Real Test with Tuned Thresholds ===\n")

# Raw model with tuned threshold
tuned_raw_preds = (real_probs_raw >= thresh_raw).astype(int).tolist()
evaluate(real_labels, tuned_raw_preds, f"TF-IDF+LR tuned@{thresh_raw:.2f} (raw)", "Real Test")

# Clean model with tuned threshold
tuned_clean_preds = (real_probs_clean >= thresh_clean).astype(int).tolist()
evaluate(real_labels, tuned_clean_preds, f"TF-IDF+LR tuned@{thresh_clean:.2f} (clean)", "Real Test")

# Compare default vs tuned
print("\n" + "=" * 60)
print("Default (0.50) vs Tuned Threshold — Real Test Comparison")
print("=" * 60)
for label, default_name, tuned_name in [
    ("raw", "TF-IDF+LR (raw)", f"TF-IDF+LR tuned@{thresh_raw:.2f} (raw)"),
    ("clean", "TF-IDF+LR (clean)", f"TF-IDF+LR tuned@{thresh_clean:.2f} (clean)"),
]:
    default = next(r for r in all_results if r["Model"] == default_name and r["Dataset"] == "Real Test")
    tuned = next(r for r in all_results if r["Model"] == tuned_name and r["Dataset"] == "Real Test")
    print(f"\n{label.upper()}:")
    print(f"  Default:  P={default['Precision']:.3f}  R={default['Recall']:.3f}  F1={default['F1']:.3f}  TP={default['TP']}  FP={default['FP']}")
    print(f"  Tuned:    P={tuned['Precision']:.3f}  R={tuned['Recall']:.3f}  F1={tuned['F1']:.3f}  TP={tuned['TP']}  FP={tuned['FP']}")
# Out:
# === Real Test with Tuned Thresholds ===
#
#
# TF-IDF+LR tuned@0.45 (raw) on Real Test:
#   Accuracy=0.967  Precision=0.897  Recall=0.333  F1=0.486
#   TP=26  FP=3  FN=52  TN=1600
#
# TF-IDF+LR tuned@0.43 (clean) on Real Test:
#   Accuracy=0.967  Precision=0.893  Recall=0.321  F1=0.472
#   TP=25  FP=3  FN=53  TN=1600
#
# ============================================================
# Default (0.50) vs Tuned Threshold — Real Test Comparison
# ============================================================
#
# RAW:
#   Default:  P=0.885  R=0.295  F1=0.442  TP=23  FP=3
#   Tuned:    P=0.897  R=0.333  F1=0.486  TP=26  FP=3
#
# CLEAN:
#   Default:  P=0.920  R=0.295  F1=0.447  TP=23  FP=2
#   Tuned:    P=0.893  R=0.321  F1=0.472  TP=25  FP=3

# %% [markdown]
# ## 6. Model 3 — Fine-tuned DistilBERT (Primary Model)\n\nDistilBERT is a distilled version of BERT with 66M parameters (vs BERT's 110M), roughly 60% faster on CPU while retaining ~97% of BERT's performance.\n\nWe use `max_length=128` tokens — the real test data averages ~88 words which fits well. Some synthetic segments may be truncated, but ad signals tend to appear early in the segment.\n\nTrained on both raw and cleaned text for comparison.

# %%
class AdDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=128):
        self.encodings = tokenizer(
            texts, truncation=True, padding="max_length",
            max_length=max_length, return_tensors="pt",
        )
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __getitem__(self, idx):
        item = {k: v[idx] for k, v in self.encodings.items()}
        item["labels"] = self.labels[idx]
        return item

    def __len__(self):
        return len(self.labels)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    p, r, f1, _ = precision_recall_fscore_support(labels, preds, average="binary", zero_division=0)
    acc = np.mean(preds == labels)
    return {"accuracy": acc, "precision": p, "recall": r, "f1": f1}

# %%
MODEL_NAME = "distilbert-base-uncased"

def train_distilbert(train_texts, val_texts, real_texts, train_labels, val_labels, real_labels, label):
    """Fine-tune DistilBERT and return predictions + probabilities on all datasets."""
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)

    train_dataset = AdDataset(train_texts, train_labels, tokenizer)
    val_dataset = AdDataset(val_texts, val_labels, tokenizer)
    real_dataset = AdDataset(real_texts, real_labels, tokenizer)

    training_args = TrainingArguments(
        output_dir=f"./results/distilbert_{label}",
        num_train_epochs=7,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=32,
        eval_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="f1",
        logging_steps=50,
        use_cpu=DEVICE == "cpu",
        fp16=DEVICE == "cuda",
        report_to="none",
        seed=42,
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        compute_metrics=compute_metrics,
        callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
    )

    print(f"Training DistilBERT ({label})...")
    trainer.train()

    # Get logits and convert to probabilities
    val_output = trainer.predict(val_dataset)
    real_output = trainer.predict(real_dataset)

    val_probs = torch.softmax(torch.tensor(val_output.predictions), dim=-1)[:, 1].numpy()
    real_probs = torch.softmax(torch.tensor(real_output.predictions), dim=-1)[:, 1].numpy()

    val_preds = (val_probs >= 0.5).astype(int)
    real_preds = (real_probs >= 0.5).astype(int)

    evaluate(val_labels, val_preds.tolist(), f"DistilBERT ({label})", "Validation")
    evaluate(real_labels, real_preds.tolist(), f"DistilBERT ({label})", "Real Test")

    return trainer, real_preds, val_probs, real_probs

# %%
# Train on raw text
trainer_raw, bert_raw_real_preds, bert_val_probs_raw, bert_real_probs_raw = train_distilbert(
    train_texts_raw, val_texts_raw, real_texts_raw,
    train_labels, val_labels, real_labels, "raw"
)
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# vocab_projector.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# pre_classifier.weight   | MISSING    |
# pre_classifier.bias     | MISSING    |
# classifier.weight       | MISSING    |
# classifier.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Training DistilBERT (raw)...
#     <div>
#
#       <progress value='840' max='1470' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 840/1470 03:35 < 02:41, 3.89 it/s, Epoch 4/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.023297</td>
#       <td>0.002088</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.022347</td>
#       <td>0.000578</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000181</td>
#       <td>0.000133</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000112</td>
#       <td>0.000076</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# There were missing keys in the checkpoint model loaded: ['distilbert.embeddings.LayerNorm.weight', 'distilbert.embeddings.LayerNorm.bias'].
# There were unexpected keys in the checkpoint model loaded: ['distilbert.embeddings.LayerNorm.beta', 'distilbert.embeddings.LayerNorm.gamma'].
# DistilBERT (raw) on Validation:
#   Accuracy=1.000  Precision=1.000  Recall=1.000  F1=1.000
#   TP=200  FP=0  FN=0  TN=200
#
# DistilBERT (raw) on Real Test:
#   Accuracy=0.958  Precision=0.537  Recall=0.744  F1=0.624
#   TP=58  FP=50  FN=20  TN=1553

# %%
# Train on cleaned text
trainer_clean, bert_clean_real_preds, bert_val_probs_clean, bert_real_probs_clean = train_distilbert(
    train_texts_clean, val_texts_clean, real_texts_clean,
    train_labels, val_labels, real_labels, "clean"
)
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertForSequenceClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# vocab_projector.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# pre_classifier.weight   | MISSING    |
# pre_classifier.bias     | MISSING    |
# classifier.weight       | MISSING    |
# classifier.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Training DistilBERT (clean)...
#     <div>
#
#       <progress value='840' max='1470' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 840/1470 03:00 < 02:16, 4.63 it/s, Epoch 4/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.019350</td>
#       <td>0.001574</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000451</td>
#       <td>0.000273</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000180</td>
#       <td>0.000125</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000118</td>
#       <td>0.000079</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# There were missing keys in the checkpoint model loaded: ['distilbert.embeddings.LayerNorm.weight', 'distilbert.embeddings.LayerNorm.bias'].
# There were unexpected keys in the checkpoint model loaded: ['distilbert.embeddings.LayerNorm.beta', 'distilbert.embeddings.LayerNorm.gamma'].
# DistilBERT (clean) on Validation:
#   Accuracy=1.000  Precision=1.000  Recall=1.000  F1=1.000
#   TP=200  FP=0  FN=0  TN=200
#
# DistilBERT (clean) on Real Test:
#   Accuracy=0.942  Precision=0.419  Recall=0.667  F1=0.515
#   TP=52  FP=72  FN=26  TN=1531

# %% [markdown]
# ## 6b. Threshold Tuning for DistilBERT
#
# Same approach as section 5b: sweep thresholds on the validation set optimizing F2 (recall-weighted), then re-evaluate on the real test set. This corrects for the train/test class imbalance mismatch (50/50 training vs ~3% ads in real data).

# %%
# Threshold sweep on validation set for DistilBERT
print("=== DistilBERT Threshold Sweep on Validation Set (F2 optimization) ===\n")
bert_thresh_raw, bert_ts_raw, bert_fs_raw, bert_ps_raw, bert_rs_raw = sweep_threshold(
    val_labels, bert_val_probs_raw, "DistilBERT (raw)"
)
bert_thresh_clean, bert_ts_clean, bert_fs_clean, bert_ps_clean, bert_rs_clean = sweep_threshold(
    val_labels, bert_val_probs_clean, "DistilBERT (clean)"
)
# Out:
# === DistilBERT Threshold Sweep on Validation Set (F2 optimization) ===
#
# DistilBERT (raw):
#   Default (0.50) — F2=1.000
#   Optimal (0.01) — F2=1.000
#   At optimal: Precision=1.000, Recall=1.000
# DistilBERT (clean):
#   Default (0.50) — F2=1.000
#   Optimal (0.01) — F2=1.000
#   At optimal: Precision=1.000, Recall=1.000

# %%
# F2 vs threshold and PR curves for DistilBERT
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

for ax, ts, fs, thresh, label in [
    (axes[0, 0], bert_ts_raw, bert_fs_raw, bert_thresh_raw, "DistilBERT (raw)"),
    (axes[0, 1], bert_ts_clean, bert_fs_clean, bert_thresh_clean, "DistilBERT (clean)"),
]:
    ax.plot(ts, fs, color="steelblue", linewidth=2)
    ax.axvline(0.5, color="gray", linestyle="--", alpha=0.5, label="Default (0.50)")
    ax.axvline(thresh, color="red", linestyle="--", label=f"Optimal ({thresh:.2f})")
    ax.set_xlabel("Threshold")
    ax.set_ylabel("F2 Score")
    ax.set_title(f"{label} — F2 vs Threshold")
    ax.legend()
    ax.set_xlim(0, 1)

for ax, probs, labels, label in [
    (axes[1, 0], bert_val_probs_raw, val_labels, "DistilBERT (raw)"),
    (axes[1, 1], bert_val_probs_clean, val_labels, "DistilBERT (clean)"),
]:
    precision, recall, thresholds = precision_recall_curve(labels, probs)
    ax.plot(recall, precision, color="coral", linewidth=2)
    ax.set_xlabel("Recall")
    ax.set_ylabel("Precision")
    ax.set_title(f"{label} — Precision-Recall Curve (Val)")
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1.05)
    ax.fill_between(recall, precision, alpha=0.1, color="coral")

plt.suptitle("Threshold Tuning — DistilBERT (Validation Set)", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
# Re-evaluate DistilBERT on real test using tuned thresholds
print("=== DistilBERT Real Test with Tuned Thresholds ===\n")

tuned_bert_raw_preds = (bert_real_probs_raw >= bert_thresh_raw).astype(int).tolist()
evaluate(real_labels, tuned_bert_raw_preds, f"DistilBERT tuned@{bert_thresh_raw:.2f} (raw)", "Real Test")

tuned_bert_clean_preds = (bert_real_probs_clean >= bert_thresh_clean).astype(int).tolist()
evaluate(real_labels, tuned_bert_clean_preds, f"DistilBERT tuned@{bert_thresh_clean:.2f} (clean)", "Real Test")

# Compare default vs tuned
print("\n" + "=" * 60)
print("Default (0.50) vs Tuned Threshold — DistilBERT Real Test")
print("=" * 60)
for label, default_name, tuned_name in [
    ("raw", "DistilBERT (raw)", f"DistilBERT tuned@{bert_thresh_raw:.2f} (raw)"),
    ("clean", "DistilBERT (clean)", f"DistilBERT tuned@{bert_thresh_clean:.2f} (clean)"),
]:
    default = next(r for r in all_results if r["Model"] == default_name and r["Dataset"] == "Real Test")
    tuned = next(r for r in all_results if r["Model"] == tuned_name and r["Dataset"] == "Real Test")
    print(f"\n{label.upper()}:")
    print(f"  Default:  P={default['Precision']:.3f}  R={default['Recall']:.3f}  F1={default['F1']:.3f}  TP={default['TP']}  FP={default['FP']}")
    print(f"  Tuned:    P={tuned['Precision']:.3f}  R={tuned['Recall']:.3f}  F1={tuned['F1']:.3f}  TP={tuned['TP']}  FP={tuned['FP']}")
# Out:
# === DistilBERT Real Test with Tuned Thresholds ===
#
#
# DistilBERT tuned@0.01 (raw) on Real Test:
#   Accuracy=0.932  Precision=0.389  Recall=0.808  F1=0.525
#   TP=63  FP=99  FN=15  TN=1504
#
# DistilBERT tuned@0.01 (clean) on Real Test:
#   Accuracy=0.927  Precision=0.353  Recall=0.692  F1=0.468
#   TP=54  FP=99  FN=24  TN=1504
#
# ============================================================
# Default (0.50) vs Tuned Threshold — DistilBERT Real Test
# ============================================================
#
# RAW:
#   Default:  P=0.537  R=0.744  F1=0.624  TP=58  FP=50
#   Tuned:    P=0.389  R=0.808  F1=0.525  TP=63  FP=99
#
# CLEAN:
#   Default:  P=0.419  R=0.667  F1=0.515  TP=52  FP=72
#   Tuned:    P=0.353  R=0.692  F1=0.468  TP=54  FP=99

# %% [markdown]
# ## 7. Comparison & Evaluation
#
# With a heavily imbalanced real test set (~3% ads), accuracy is misleading — a model predicting all non-ad gets ~97%. We focus on **precision, recall, and F1** as the meaningful metrics.
#
# Per the project proposal, recall is weighted more heavily: missing an ad is less disruptive than incorrectly flagging real content.

# %%
# Comparison table
print(f"{'Model':<25} {'Dataset':<12} {'Acc':>6} {'Prec':>6} {'Rec':>6} {'F1':>6} {'TP':>4} {'FP':>4} {'FN':>4} {'TN':>5}")
print("-" * 95)
for r in all_results:
    print(f"{r['Model']:<25} {r['Dataset']:<12} {r['Accuracy']:>6.3f} {r['Precision']:>6.3f} {r['Recall']:>6.3f} {r['F1']:>6.3f} {r['TP']:>4} {r['FP']:>4} {r['FN']:>4} {r['TN']:>5}")
# Out:
# Model                     Dataset         Acc   Prec    Rec     F1   TP   FP   FN    TN
# -----------------------------------------------------------------------------------------------
# Keyword                   Validation    0.865  0.980  0.745  0.847  149    3   51   197
# Keyword                   Real Test     0.965  0.828  0.308  0.449   24    5   54  1598
# TF-IDF+LR (raw)           Validation    1.000  1.000  1.000  1.000  200    0    0   200
# TF-IDF+LR (raw)           Real Test     0.965  0.885  0.295  0.442   23    3   55  1600
# TF-IDF+LR (clean)         Validation    1.000  1.000  1.000  1.000  200    0    0   200
# TF-IDF+LR (clean)         Real Test     0.966  0.920  0.295  0.447   23    2   55  1601
# TF-IDF+LR tuned@0.45 (raw) Real Test     0.967  0.897  0.333  0.486   26    3   52  1600
# TF-IDF+LR tuned@0.43 (clean) Real Test     0.967  0.893  0.321  0.472   25    3   53  1600
# DistilBERT (raw)          Validation    1.000  1.000  1.000  1.000  200    0    0   200
# DistilBERT (raw)          Real Test     0.958  0.537  0.744  0.624   58   50   20  1553
# DistilBERT (clean)        Validation    1.000  1.000  1.000  1.000  200    0    0   200
# DistilBERT (clean)        Real Test     0.942  0.419  0.667  0.515   52   72   26  1531
# DistilBERT tuned@0.01 (raw) Real Test     0.932  0.389  0.808  0.525   63   99   15  1504
# DistilBERT tuned@0.01 (clean) Real Test     0.927  0.353  0.692  0.468   54   99   24  1504

# %%
# Confusion matrices for real test set (all 5 model variants)
real_test_results = [r for r in all_results if r["Dataset"] == "Real Test"]
n_models = len(real_test_results)
fig, axes = plt.subplots(1, n_models, figsize=(4 * n_models, 4))
if n_models == 1:
    axes = [axes]

for ax, r in zip(axes, real_test_results):
    cm = np.array([[r["TN"], r["FP"]], [r["FN"], r["TP"]]])
    disp = ConfusionMatrixDisplay(cm, display_labels=["Non-Ad", "Ad"])
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    ax.set_title(r["Model"], fontsize=10)

plt.suptitle("Confusion Matrices — Real Test Set", fontsize=13, y=1.02)
plt.tight_layout()
plt.show()

# %%
# Bar chart comparing F1 and Recall on real test set
real_models = [r["Model"] for r in real_test_results]
real_f1 = [r["F1"] for r in real_test_results]
real_recall = [r["Recall"] for r in real_test_results]

x = np.arange(len(real_models))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x - width/2, real_f1, width, label="F1", color="steelblue")
ax.bar(x + width/2, real_recall, width, label="Recall", color="coral")
ax.set_ylabel("Score")
ax.set_title("F1 and Recall on Real Test Set")
ax.set_xticks(x)
ax.set_xticklabels(real_models, rotation=15, ha="right")
ax.legend()
ax.set_ylim(0, 1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Error Analysis
#
# We inspect false negatives (missed ads) and false positives (incorrectly flagged non-ads) across the held-out test videos to understand model behavior.

# %%
# Collect all real test predictions into a dict for analysis
model_preds = {
    "Keyword": kw_real_preds,
    "TF-IDF+LR (raw)": lr_raw_real_preds.tolist(),
    "TF-IDF+LR (clean)": lr_clean_real_preds.tolist(),
    f"TF-IDF+LR tuned (raw)": tuned_raw_preds,
    f"TF-IDF+LR tuned (clean)": tuned_clean_preds,
    "DistilBERT (raw)": bert_raw_real_preds.tolist(),
    "DistilBERT (clean)": bert_clean_real_preds.tolist(),
    "DistilBERT tuned (raw)": tuned_bert_raw_preds,
    "DistilBERT tuned (clean)": tuned_bert_clean_preds,
}

# False negatives — which real ads did each model miss?
print("=== False Negatives (Missed Ads) ===\n")
ad_indices = [i for i, l in enumerate(real_labels) if l == 1]
for idx in ad_indices:
    text_preview = real_texts[idx][:120]
    vid = real_test_data[idx]["video_id"]
    missed_by = [name for name, preds in model_preds.items() if preds[idx] == 0]
    caught_by = [name for name, preds in model_preds.items() if preds[idx] == 1]
    print(f"Segment {idx} ({vid}):")
    print(f"  \"{text_preview}...\"")
    print(f"  Caught by: {caught_by if caught_by else 'NONE'}")
    print(f"  Missed by: {missed_by if missed_by else 'NONE'}")
    print()
# Out:
# === False Negatives (Missed Ads) ===
#
# Segment 145 (vif8NQcjVf0):
#   "And in the meantime, my, my favorite answer is eliminate waste. You know, we've, we've got all that idle power. I want t..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 146 (vif8NQcjVf0):
#   "We got perplexity for curiosity driven knowledge exploration, Shopify for selling stuff online, element for electrolytes..."
#   Caught by: ['TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword']
#
# Segment 369 (1SJiTwbSI58):
#   "Can you recognize these guitars from a single note? Could you recognize the Vivaan? Abs versus air Clapton? Yeah. All ri..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 370 (1SJiTwbSI58):
#   "knowledge exploration. Choose what is in my friends. And now back to my conversation with Rick Biano. What do you think ..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 474 (1SJiTwbSI58):
#   "and separate that stuff. And so it's really helpful for things like that. And now once again, quick 30 seconds, thank yo..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 561 (YSJY3DvnybE):
#   "And that's what today's sponsor, Saley, is all about. And right now I'm traveling to New York, and when I touch down, I'..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 562 (YSJY3DvnybE):
#   "And then right here, check out, you can apply the code Veritasium to get 15% off on your order. And the best part of thi..."
#   Caught by: ['Keyword', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 563 (YSJY3DvnybE):
#   "It's also so much better than swapping tiny physical sim cards. Once the Saley eSIM is installed, you don't have to inst..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 564 (YSJY3DvnybE):
#   "and advanced online security tools. So download the Saley app via the QR code that's on screen, and when you're at check..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 624 (9szhjhO9epA):
#   "be okay. But a more obvious reason for the zipper's popularity is that it's just so easy to use. How much quicker is a z..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 625 (9szhjhO9epA):
#   "If you're trying to keep track of everything manually, it's a pretty slow process and it's super easy to miss something...."
#   Caught by: ['DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)']
#
# Segment 626 (9szhjhO9epA):
#   "the most important messages and zip them together into one central hub. It's also a great research tool. So if there's a..."
#   Caught by: ['Keyword', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 627 (9szhjhO9epA):
#   "open-cloth or click on the link in the description. You make sure you use CodeVertafzium to get an exclusive discount on..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 693 (Ol18JoeXlVI):
#   "should matter in your decision. So the question is, what do you do? Do you pick both boxes or do you just pick the myste..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 694 (Ol18JoeXlVI):
#   "correlation. Do we think that correlation is the same as causation? But how can you tease out what's causation and what'..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 695 (Ol18JoeXlVI):
#   "think instead of just nodding along with an explanation. Brilliant helps you build skills in math and coding with step-b..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 696 (Ol18JoeXlVI):
#   "you're 10 or 110, the practice sets and reviews are customized to help you advance at your ideal pace. So how can you te..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 697 (Ol18JoeXlVI):
#   "for a full 30 days, scan this QR code or go to brilliant.org slashbaratacim. I will put that link down in the descriptio..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 747 (aoag03mSuXQ):
#   "All indications are that JITAN is a great contributor, and this puts Rich at ease, so he lets his guard down. And that's..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 748 (aoag03mSuXQ):
#   "I use NordVPN whenever I'm traveling, or working on public Wi-Fi, because it means that I don't have to think about who'..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 749 (aoag03mSuXQ):
#   "I haven't tried it yet, but that sounds fascinating. So if you want to try it, you can get the best deal by going to Nor..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 825 (P-4pbFcERnk):
#   "So if there's anything he wanted to do, he sort of just did it. And I feel like I'm quite the opposite. You know, when I..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 826 (P-4pbFcERnk):
#   "And I'm so glad that they did. Because when Derek and I made my first video, I fell in love with it. So if there's anyth..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 827 (P-4pbFcERnk):
#   "With Hostinger, you don't need any kind of crazy tech skills. It's all frictionless and affordable. So you can go from a..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 973 (MiUHjLxm3V0):
#   "And maybe, at least to me, it's a reminder that it's good to be a little unreasonable. At least in some of the big parts..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 974 (MiUHjLxm3V0):
#   "Bit by bit, you gain knowledge. And that's where today's video sponsor, Brilliant, comes in. Brilliant helps you excel i..."
#   Caught by: ['TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword']
#
# Segment 975 (MiUHjLxm3V0):
#   "designs practice sets, and refuse customized for you. And then it helps you advance at your ideal pace. There is always ..."
#   Caught by: ['DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)']
#
# Segment 976 (MiUHjLxm3V0):
#   "or understanding the physics that will take us beyond EUV. Brilliant will help you get there. And if like me, you've res..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 991 (Y-W-w8yNiKU):
#   "Klein's work was pretty well received by a number of his colleagues. In fact, it turned out that two other physicists, W..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 992 (Y-W-w8yNiKU):
#   "Simple enough, you just need to write a couple thousand lines of CSS, JavaScript, or HTML, or else pay someone a few tho..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (clean)']
#
# Segment 993 (Y-W-w8yNiKU):
#   "And once you're happy, you're online immediately on a domain that's included with the plan. That whole process is fast a..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1067 (HBluLfX2F_k):
#   "And that same idea, one outlier can dominate the average, shows up online too. A handful of companies, servers, and data..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1068 (HBluLfX2F_k):
#   "NordVPN encrypts your internet traffic so your personal data stays private, even when the wider system isn't. It protect..."
#   Caught by: ['TF-IDF+LR tuned (raw)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1069 (HBluLfX2F_k):
#   "Just scan this QR code or go to nordvpn.com slashbaritasm to get a huge discount on a two-year plan plus four extra mont..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1211 (QtxVdC7pBQM):
#   "blade in my kitchen but with the help from this video sponsor KiwiCo I can grow a crystal garden with my kids. This mont..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 1212 (QtxVdC7pBQM):
#   "are arranged. Pretty soon we were talking about how metals are crystalline too and setting ourselves the challenge of gr..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1213 (QtxVdC7pBQM):
#   "crates also make a great gift for the holidays. It's creative hands on and gives kids something they can actually make a..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1235 (eXa2ndhmatI):
#   "And what sort of strings they try to pull it because if they aren't able to do anything about it, then Neo is just going..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1236 (eXa2ndhmatI):
#   "So it's kind of if you know you know design, but you can put them on anything colorful for fun. At least that's what I'v..."
#   Caught by: ['DistilBERT (clean)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT tuned (raw)']
#
# Segment 1265 (iGeXGdYE7UE):
#   "and it's now the easiest laptop for reviewers to recommend because that's been the MacBook Air for years and this is 90 ..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1266 (iGeXGdYE7UE):
#   "from the 80s and 90s and they actually painstakingly color matched the shades and hues for nearly every MacBook. Space B..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1267 (iGeXGdYE7UE):
#   "but because it's actually a really good product, adds no thickness, protects it from scratches and it's actually very du..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1286 (kBX5WH9b4M4):
#   "Ridge was started 13 years ago by Paul and Daniel Cain with one pretty simple goal, gear built better. And that mission ..."
#   Caught by: ['Keyword']
#   Missed by: ['TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1287 (kBX5WH9b4M4):
#   "because it's good stuff, the tracker card, which works with Apple Find My. And it has a really loud chime to help you fi..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1288 (kBX5WH9b4M4):
#   "So don't wait or you miss out on up to 40% off. Check it out at the link below, ridge.com slash MKBHD. Thanks for watchi..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1306 (FRI78tq9Eik):
#   "What the button is for if you're planning on grabbing an S26 Ultra would you rather have a case for it that looks like t..."
#   Caught by: ['DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 1307 (FRI78tq9Eik):
#   "You know just in case and fun fact even though Samsung just announced the phone D brand's entire S26 lineup the zero yel..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1308 (FRI78tq9Eik):
#   "So D brand's new S26 lineup is available on their site and nationwide at Best Buy in the US. I'll leave a link down belo..."
#   Caught by: ['TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)']
#
# Segment 1333 (DqAKQwagCDg):
#   "like a experience that fits in your pocket so well played Xiaomi well played and shout out to rocket money for sponsorin..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 1334 (DqAKQwagCDg):
#   "that it shows that I'm paying for that I kind of forgot I was paying for but then the best part I think is that you can ..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1335 (DqAKQwagCDg):
#   "so checking savings credit card so I can actually see how much I spend on video gear versus other more responsible thing..."
#   Caught by: ['DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 1336 (DqAKQwagCDg):
#   "money dot com slash mkbhd or scan the QR code there's also going to be a link in the description if you want to check it..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1347 (ZxobPzkE4r0):
#   "money is of course something we all have to deal with every day. And for a lot of people, it's managing debt. Many don't..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1348 (ZxobPzkE4r0):
#   "Whether someone's struggling with credit cards, personal loans, or medical bills, PDS debt works to understand your fina..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1349 (ZxobPzkE4r0):
#   "which is part of why so many people have turned to them when they want to start fixing their finances. The reality is, e..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1350 (ZxobPzkE4r0):
#   "So go to pdsdett.com slashcodefusion to change your story in 30 seconds, get your free personalized assessment, and see ..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1400 (-YNk9_e4pg4):
#   "consumer generated AI still worth the cost, especially when the fallout isn't abstract anymore? So what's your take on a..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1401 (-YNk9_e4pg4):
#   "works in the first place? Well if you have, Brilliant is for you. I've found it a great way to learn or build on the ski..."
#   Caught by: ['DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)']
#
# Segment 1402 (-YNk9_e4pg4):
#   "Whether you're 10 years old or 110, it's designed for everyone from curious kids to adults. I love Brilliant's scientifi..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1403 (-YNk9_e4pg4):
#   "there's more depth than ever, from everyday data reasoning and probability to advanced problem solving and the mathemati..."
#   Caught by: ['TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword']
#
# Segment 1404 (-YNk9_e4pg4):
#   "cold fusion. Scan the QR code on the screen or click the link in the description. Brilliant's also offering our viewers ..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1414 (-q2n5DkDoMQ):
#   "So, the problems for open AI can be split into four main parts. One, the scaling problem. Two, losing market share. Thre..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1415 (-q2n5DkDoMQ):
#   "It sounds great in theory, but most people just watch a few tutorials, copy some code, and then give up. But with Boot.D..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1416 (-q2n5DkDoMQ):
#   "Their curriculum takes you through languages like Python, SQL, and Go. And when you're stuck, Boot.Dev's AI tutor, calle..."
#   Caught by: ['TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)']
#
# Segment 1417 (-q2n5DkDoMQ):
#   "There's also a 30-day no questions ask refund, and a free demo of the interactive experience on every course. So if you'..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1476 (PPJ6NJkmDAo):
#   "Because when you combine them in this particular scenario, they create a loophole. So our hack relied on a specific phon..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 1477 (PPJ6NJkmDAo):
#   "I made a ton of sense I was leaving the airport so I just responded by sending my phone number. I immediately was like, ..."
#   Caught by: NONE
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#
# Segment 1478 (PPJ6NJkmDAo):
#   "I've wondered whether me using some website has led to my personal information being exposed somewhere without me even k..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1479 (PPJ6NJkmDAo):
#   "And I really like how you can track the progress in the dashboard here. They've estimated that that saved me 70 hours an..."
#   Caught by: ['Keyword', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1480 (PPJ6NJkmDAo):
#   "And then use code Veritasium for 60% off. You can click the link below or you can scan this QR code to claim that 60% of..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1560 (jjp3WC8Unj8):
#   "That's the best. That's the best thing you see. If you're wondering what you would do with all that money, you should ch..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1561 (jjp3WC8Unj8):
#   "By adding up all of these benefits, you could unlock $1,000 or more in annual value with qualifying activities. Of cours..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1562 (jjp3WC8Unj8):
#   "as well as other cash prizes and free memberships. So to check out SoFi Plus, head to SoFi.com, slashwareatarsium, or cl..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE
#
# Segment 1620 (5aS-8QCRdGE):
#   "that there were some rumors, though, of a rollable smartphone from them that never came out. This is two years after we ..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 1657 (3w0KeFOB698):
#   "Reentry of a new spacecraft with a heat shield that nearly failed in a previous test flight, and had never carried human..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT tuned (raw)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (clean)', 'DistilBERT tuned (clean)']
#
# Segment 1658 (3w0KeFOB698):
#   "and one that stood out to me is Raycon's bone conduction headphones. They're designed a bit differently from regular hea..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1659 (3w0KeFOB698):
#   "They're built for that kind of everyday use too. You get around 13 hours of battery life, their waterproof and dustproof..."
#   Caught by: ['DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)']
#
# Segment 1660 (3w0KeFOB698):
#   "There's a reason they've built that reputation. So if you're looking for something practical this Mother's Day, or even ..."
#   Caught by: ['Keyword', 'TF-IDF+LR (raw)', 'TF-IDF+LR (clean)', 'TF-IDF+LR tuned (raw)', 'TF-IDF+LR tuned (clean)', 'DistilBERT (raw)', 'DistilBERT (clean)', 'DistilBERT tuned (raw)', 'DistilBERT tuned (clean)']
#   Missed by: NONE

# %%
# False positives — sample of non-ad segments incorrectly flagged (best model)
# Use the model with fewest FP on real test as reference
best_model = min(real_test_results, key=lambda r: r["FP"] if r["FP"] > 0 else float("inf"))
best_name = best_model["Model"]
best_preds = model_preds[best_name]

fp_indices = [i for i in range(len(real_labels)) if real_labels[i] == 0 and best_preds[i] == 1]
print(f"=== False Positives for {best_name} ({len(fp_indices)} total) ===\n")
for idx in fp_indices[:10]:  # show up to 10
    text_preview = real_texts[idx][:150]
    vid = real_test_data[idx]["video_id"]
    print(f"Segment {idx} ({vid}):")
    print(f"  \"{text_preview}...\"")
    print()
# Out:
# === False Positives for TF-IDF+LR (clean) (2 total) ===
#
# Segment 1042 (Y-W-w8yNiKU):
#   "We're coming close to the final few days of the Kickstarter campaign. So this is your last chance to get your hands on the exclusive launch edition. I..."
#
# Segment 1133 (HBluLfX2F_k):
#   "But I'm glad to say that right now, we have enabled worldwide shipping. So no matter where you are in the world, you can get your very own copy. To re..."

# %%
# Per-video recall breakdown
print("=== Per-Video Recall Breakdown ===\n")
for name, preds in model_preds.items():
    print(f"{name}:")
    for vid in sorted(set(r["video_id"] for r in real_test_data)):
        vid_mask = [i for i, r in enumerate(real_test_data) if r["video_id"] == vid]
        vid_ads = [i for i in vid_mask if real_labels[i] == 1]
        if not vid_ads:
            continue
        caught = sum(1 for i in vid_ads if preds[i] == 1)
        print(f"  {vid}: {caught}/{len(vid_ads)} ads detected")
    print()
# Out:
# === Per-Video Recall Breakdown ===
#
# Keyword:
#   -YNk9_e4pg4: 1/5 ads detected
#   -q2n5DkDoMQ: 1/4 ads detected
#   1SJiTwbSI58: 2/3 ads detected
#   3w0KeFOB698: 1/4 ads detected
#   5aS-8QCRdGE: 0/1 ads detected
#   9szhjhO9epA: 2/4 ads detected
#   DqAKQwagCDg: 1/4 ads detected
#   FRI78tq9Eik: 0/3 ads detected
#   HBluLfX2F_k: 1/3 ads detected
#   MiUHjLxm3V0: 1/4 ads detected
#   Ol18JoeXlVI: 1/5 ads detected
#   P-4pbFcERnk: 1/3 ads detected
#   PPJ6NJkmDAo: 2/5 ads detected
#   QtxVdC7pBQM: 1/3 ads detected
#   Y-W-w8yNiKU: 1/3 ads detected
#   YSJY3DvnybE: 2/4 ads detected
#   ZxobPzkE4r0: 1/4 ads detected
#   aoag03mSuXQ: 1/3 ads detected
#   eXa2ndhmatI: 0/2 ads detected
#   iGeXGdYE7UE: 0/3 ads detected
#   jjp3WC8Unj8: 1/3 ads detected
#   kBX5WH9b4M4: 2/3 ads detected
#   vif8NQcjVf0: 1/2 ads detected
#
# TF-IDF+LR (raw):
#   -YNk9_e4pg4: 2/5 ads detected
#   -q2n5DkDoMQ: 1/4 ads detected
#   1SJiTwbSI58: 2/3 ads detected
#   3w0KeFOB698: 1/4 ads detected
#   5aS-8QCRdGE: 0/1 ads detected
#   9szhjhO9epA: 1/4 ads detected
#   DqAKQwagCDg: 1/4 ads detected
#   FRI78tq9Eik: 0/3 ads detected
#   HBluLfX2F_k: 1/3 ads detected
#   MiUHjLxm3V0: 2/4 ads detected
#   Ol18JoeXlVI: 1/5 ads detected
#   P-4pbFcERnk: 1/3 ads detected
#   PPJ6NJkmDAo: 1/5 ads detected
#   QtxVdC7pBQM: 1/3 ads detected
#   Y-W-w8yNiKU: 1/3 ads detected
#   YSJY3DvnybE: 1/4 ads detected
#   ZxobPzkE4r0: 1/4 ads detected
#   aoag03mSuXQ: 1/3 ads detected
#   eXa2ndhmatI: 0/2 ads detected
#   iGeXGdYE7UE: 0/3 ads detected
#   jjp3WC8Unj8: 1/3 ads detected
#   kBX5WH9b4M4: 1/3 ads detected
#   vif8NQcjVf0: 2/2 ads detected
#
# TF-IDF+LR (clean):
#   -YNk9_e4pg4: 2/5 ads detected
#   -q2n5DkDoMQ: 1/4 ads detected
#   1SJiTwbSI58: 2/3 ads detected
#   3w0KeFOB698: 1/4 ads detected
#   5aS-8QCRdGE: 0/1 ads detected
#   9szhjhO9epA: 1/4 ads detected
#   DqAKQwagCDg: 1/4 ads detected
#   FRI78tq9Eik: 0/3 ads detected
#   HBluLfX2F_k: 1/3 ads detected
#   MiUHjLxm3V0: 2/4 ads detected
#   Ol18JoeXlVI: 1/5 ads detected
#   P-4pbFcERnk: 1/3 ads detected
#   PPJ6NJkmDAo: 1/5 ads detected
#   QtxVdC7pBQM: 1/3 ads detected
#   Y-W-w8yNiKU: 1/3 ads detected
#   YSJY3DvnybE: 1/4 ads detected
#   ZxobPzkE4r0: 1/4 ads detected
#   aoag03mSuXQ: 1/3 ads detected
#   eXa2ndhmatI: 0/2 ads detected
#   iGeXGdYE7UE: 0/3 ads detected
#   jjp3WC8Unj8: 1/3 ads detected
#   kBX5WH9b4M4: 1/3 ads detected
#   vif8NQcjVf0: 2/2 ads detected
#
# TF-IDF+LR tuned (raw):
#   -YNk9_e4pg4: 2/5 ads detected
#   -q2n5DkDoMQ: 2/4 ads detected
#   1SJiTwbSI58: 2/3 ads detected
#   3w0KeFOB698: 1/4 ads detected
#   5aS-8QCRdGE: 0/1 ads detected
#   9szhjhO9epA: 1/4 ads detected
#   DqAKQwagCDg: 1/4 ads detected
#   FRI78tq9Eik: 1/3 ads detected
#   HBluLfX2F_k: 2/3 ads detected
#   MiUHjLxm3V0: 2/4 ads detected
#   Ol18JoeXlVI: 1/5 ads detected
#   P-4pbFcERnk: 1/3 ads detected
#   PPJ6NJkmDAo: 1/5 ads detected
#   QtxVdC7pBQM: 1/3 ads detected
#   Y-W-w8yNiKU: 1/3 ads detected
#   YSJY3DvnybE: 1/4 ads detected
#   ZxobPzkE4r0: 1/4 ads detected
#   aoag03mSuXQ: 1/3 ads detected
#   eXa2ndhmatI: 0/2 ads detected
#   iGeXGdYE7UE: 0/3 ads detected
#   jjp3WC8Unj8: 1/3 ads detected
#   kBX5WH9b4M4: 1/3 ads detected
#   vif8NQcjVf0: 2/2 ads detected
#
# TF-IDF+LR tuned (clean):
#   -YNk9_e4pg4: 2/5 ads detected
#   -q2n5DkDoMQ: 2/4 ads detected
#   1SJiTwbSI58: 2/3 ads detected
#   3w0KeFOB698: 1/4 ads detected
#   5aS-8QCRdGE: 0/1 ads detected
#   9szhjhO9epA: 1/4 ads detected
#   DqAKQwagCDg: 1/4 ads detected
#   FRI78tq9Eik: 1/3 ads detected
#   HBluLfX2F_k: 1/3 ads detected
#   MiUHjLxm3V0: 2/4 ads detected
#   Ol18JoeXlVI: 1/5 ads detected
#   P-4pbFcERnk: 1/3 ads detected
#   PPJ6NJkmDAo: 1/5 ads detected
#   QtxVdC7pBQM: 1/3 ads detected
#   Y-W-w8yNiKU: 1/3 ads detected
#   YSJY3DvnybE: 1/4 ads detected
#   ZxobPzkE4r0: 1/4 ads detected
#   aoag03mSuXQ: 1/3 ads detected
#   eXa2ndhmatI: 0/2 ads detected
#   iGeXGdYE7UE: 0/3 ads detected
#   jjp3WC8Unj8: 1/3 ads detected
#   kBX5WH9b4M4: 1/3 ads detected
#   vif8NQcjVf0: 2/2 ads detected
#
# DistilBERT (raw):
#   -YNk9_e4pg4: 3/5 ads detected
#   -q2n5DkDoMQ: 4/4 ads detected
#   1SJiTwbSI58: 2/3 ads detected
#   3w0KeFOB698: 4/4 ads detected
#   5aS-8QCRdGE: 1/1 ads detected
#   9szhjhO9epA: 3/4 ads detected
#   DqAKQwagCDg: 2/4 ads detected
#   FRI78tq9Eik: 1/3 ads detected
#   HBluLfX2F_k: 3/3 ads detected
#   MiUHjLxm3V0: 2/4 ads detected
#   Ol18JoeXlVI: 4/5 ads detected
#   P-4pbFcERnk: 3/3 ads detected
#   PPJ6NJkmDAo: 4/5 ads detected
#   QtxVdC7pBQM: 2/3 ads detected
#   Y-W-w8yNiKU: 2/3 ads detected
#   YSJY3DvnybE: 4/4 ads detected
#   ZxobPzkE4r0: 2/4 ads detected
#   aoag03mSuXQ: 3/3 ads detected
#   eXa2ndhmatI: 0/2 ads detected
#   iGeXGdYE7UE: 2/3 ads detected
#   jjp3WC8Unj8: 3/3 ads detected
#   kBX5WH9b4M4: 2/3 ads detected
#   vif8NQcjVf0: 2/2 ads detected
#
# DistilBERT (clean):
#   -YNk9_e4pg4: 4/5 ads detected
#   -q2n5DkDoMQ: 4/4 ads detected
#   1SJiTwbSI58: 2/3 ads detected
#   3w0KeFOB698: 3/4 ads detected
#   5aS-8QCRdGE: 0/1 ads detected
#   9szhjhO9epA: 2/4 ads detected
#   DqAKQwagCDg: 1/4 ads detected
#   FRI78tq9Eik: 1/3 ads detected
#   HBluLfX2F_k: 3/3 ads detected
#   MiUHjLxm3V0: 3/4 ads detected
#   Ol18JoeXlVI: 3/5 ads detected
#   P-4pbFcERnk: 2/3 ads detected
#   PPJ6NJkmDAo: 3/5 ads detected
#   QtxVdC7pBQM: 1/3 ads detected
#   Y-W-w8yNiKU: 1/3 ads detected
#   YSJY3DvnybE: 4/4 ads detected
#   ZxobPzkE4r0: 2/4 ads detected
#   aoag03mSuXQ: 3/3 ads detected
#   eXa2ndhmatI: 1/2 ads detected
#   iGeXGdYE7UE: 2/3 ads detected
#   jjp3WC8Unj8: 3/3 ads detected
#   kBX5WH9b4M4: 2/3 ads detected
#   vif8NQcjVf0: 2/2 ads detected
#
# DistilBERT tuned (raw):
#   -YNk9_e4pg4: 4/5 ads detected
#   -q2n5DkDoMQ: 4/4 ads detected
#   1SJiTwbSI58: 2/3 ads detected
#   3w0KeFOB698: 4/4 ads detected
#   5aS-8QCRdGE: 1/1 ads detected
#   9szhjhO9epA: 4/4 ads detected
#   DqAKQwagCDg: 3/4 ads detected
#   FRI78tq9Eik: 2/3 ads detected
#   HBluLfX2F_k: 3/3 ads detected
#   MiUHjLxm3V0: 3/4 ads detected
#   Ol18JoeXlVI: 4/5 ads detected
#   P-4pbFcERnk: 3/3 ads detected
#   PPJ6NJkmDAo: 4/5 ads detected
#   QtxVdC7pBQM: 2/3 ads detected
#   Y-W-w8yNiKU: 2/3 ads detected
#   YSJY3DvnybE: 4/4 ads detected
#   ZxobPzkE4r0: 2/4 ads detected
#   aoag03mSuXQ: 3/3 ads detected
#   eXa2ndhmatI: 0/2 ads detected
#   iGeXGdYE7UE: 2/3 ads detected
#   jjp3WC8Unj8: 3/3 ads detected
#   kBX5WH9b4M4: 2/3 ads detected
#   vif8NQcjVf0: 2/2 ads detected
#
# DistilBERT tuned (clean):
#   -YNk9_e4pg4: 4/5 ads detected
#   -q2n5DkDoMQ: 4/4 ads detected
#   1SJiTwbSI58: 2/3 ads detected
#   3w0KeFOB698: 3/4 ads detected
#   5aS-8QCRdGE: 0/1 ads detected
#   9szhjhO9epA: 3/4 ads detected
#   DqAKQwagCDg: 1/4 ads detected
#   FRI78tq9Eik: 1/3 ads detected
#   HBluLfX2F_k: 3/3 ads detected
#   MiUHjLxm3V0: 3/4 ads detected
#   Ol18JoeXlVI: 3/5 ads detected
#   P-4pbFcERnk: 2/3 ads detected
#   PPJ6NJkmDAo: 3/5 ads detected
#   QtxVdC7pBQM: 1/3 ads detected
#   Y-W-w8yNiKU: 2/3 ads detected
#   YSJY3DvnybE: 4/4 ads detected
#   ZxobPzkE4r0: 2/4 ads detected
#   aoag03mSuXQ: 3/3 ads detected
#   eXa2ndhmatI: 1/2 ads detected
#   iGeXGdYE7UE: 2/3 ads detected
#   jjp3WC8Unj8: 3/3 ads detected
#   kBX5WH9b4M4: 2/3 ads detected
#   vif8NQcjVf0: 2/2 ads detected

# %% [markdown]
# ## 9. Conclusion
#
# ### Findings
#
# - **Three approaches** were compared: keyword/regex baseline, TF-IDF + logistic regression, and fine-tuned DistilBERT
# - Each learning-based model was trained on both **raw and filler-cleaned** text to measure the effect of preprocessing
# - **Mixing real training data** from 8 videos into the synthetic training set helps bridge the synthetic-to-real domain gap — the model sees real Whisper transcription artifacts and genuine ad phrasing during training
# - The test set uses 18 held-out videos (split by video to prevent leakage)
#
# ### Limitations
#
# - **Synthetic training data**: LLM-generated text is cleaner and more uniform than real Whisper transcriptions; real data helps but the domain gap remains
# - **Class imbalance**: Real data is ~97% non-ad, requiring careful threshold tuning
# - **CPU training**: Limited to DistilBERT (66M params) rather than larger models
# - **Text-only**: No audio features used (mel spectrograms were a stretch goal)
#
# ### Future Work
#
# - Collect more real labeled data from SponsorBlock to further increase real training coverage
# - Explore audio-based CNN classifier on mel spectrograms for comparison
# - Investigate longer context windows to capture segment-level patterns
